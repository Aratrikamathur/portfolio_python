# %%
print("wellcome to abc bank \n\n Insert your card\n\n")

password=1234
choice=0
balance=100000

pin=int (input ("Enter your 4 digit pin\n"))
if pin==password:

    while choice != 4:

       print("\n\n *******MENU*******\n\n")
       print("1 == balance ")
       print("2 == Deposit money")
       print("3 == Withdraw ")
       print("4 == Cancle/n")
       print("Correct pin\n\n")

       choice=int(input("Enter Your options\n\n "))

       if choice==1:
        print("\nbalance is Rs",balance)
       elif choice ==2:
        print("\nHow much money you want to deposit in your bank account")
        dep=int(input("\n\nEnter the amount\n\n"))
        balance += dep
        print("\n\nDeposited Amount =",dep)
        print("\nNew Balance =",balance)
       elif choice==3:
        print("\nEnter the amount you want to withdraw")
        wit=int(input("Enter withdrawal Amount"))
        balance -= wit
        print("\n\nwithdrawal Amount =",wit)
        print("\n\nNew Balance =",balance)
        if wit>balance:
          print("\n\nMoney can not be withdrawn i.e Invalid Amount of Money ")
       elif choice==4:
        print("\n\nsession ended ,HAVE A NICE DAY")
        break
       else :
        print("\n\nInvalid Entry!!")
else:
    print("\n\nIncorrect pin")
# Out:
# wellcome to abc bank
#
#  Insert your card
#
#
# Enter your 4 digit pin
# 1234
#
#
#  *******MENU*******
#
#
# 1 == balance
# 2 == Deposit money
# 3 == Withdraw
# 4 == Cancle/n
# Correct pin
#
#
# Enter Your options
#
#  1
#
# balance is Rs 100000
#
#
#  *******MENU*******
#
#
# 1 == balance
# 2 == Deposit money
# 3 == Withdraw
# 4 == Cancle/n
# Correct pin
#
#
# Enter Your options
#
#  2
#
# How much money you want to deposit in your bank account
#
#
# Enter the amount
#
# 5000
#
#
# Deposited Amount = 5000
#
# New Balance = 105000
#
#
#  *******MENU*******
#
#
# 1 == balance
# 2 == Deposit money
# 3 == Withdraw
# 4 == Cancle/n
# Correct pin
#
#
# Enter Your options
#
#  3
#
# Enter the amount you want to withdraw
# Enter withdrawal Amount200000
#
#
# withdrawal Amount = 200000
#
#
# New Balance = -95000
#
#
# Money can not be withdrawn i.e Invalid Amount of Money
#
#
#  *******MENU*******
#
#
# 1 == balance
# 2 == Deposit money
# 3 == Withdraw
# 4 == Cancle/n
# Correct pin
#
#
# ...
