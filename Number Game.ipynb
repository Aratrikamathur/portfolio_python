# %%
print("You will get 5 chances")
chance=5
for i in range(chance):
  num=15
  n=int(input("Enter Number of ur choice"))
  if n==num:
   print("Congratulation! ,your input is correct")
   break
  if 10<= n <=20:
    print("You are near about")
  elif 5<= n <=25:
   print("you need to work hard  ")
  else:
    print("out of range")
else:
  print("Better luck next time")
# Out:
# You will get 5 chances
# Enter Number of ur choice15
# Congratulation! ,your input is correct
